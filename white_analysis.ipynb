# %% [markdown]
# # Classifying White Wine Based on Data from Physicochemical Tests

# %% [markdown]
# Authors: Peter Lee, Kashish Joshipura, Eric Huang

# %% [markdown]
# ## Loading in the required libraries used for classification of the data

# %%
library(tidyverse)
library(repr)
library(tidymodels)
library(kknn)
# install.packages("ggplot2")       
# install.packages("GGally")
library("ggplot2")                     
library("GGally")
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.1      ✔ purrr   1.0.0
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.5.0
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ── Attaching packages ────────────────────────────────────── tidymodels 1.0.0 ──
#
# ✔ broom        1.0.2     ✔ rsample      1.1.1
# ✔ dials        1.1.0     ✔ tune         1.0.1
# ✔ infer        1.0.4     ✔ workflows    1.1.2
# ✔ modeldata    1.1.0     ✔ workflowsets 1.0.0
# ✔ parsnip      1.0.3     ✔ yardstick    1.1.0
# ✔ recipes      1.0.3
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()
# • Use suppressPackageStartupMessages() to eliminate package startup messages
#
# Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this project, we attempt to build a classification model using the k-nearest neighbor algorithm to classify the wine only based on the physicochemical variable. This model can help the wine rating association or connoisseur understand the relationship between physicochemical and sensory factors better, and thus determine the rate of the wine more accurately or more objectively.
# <br>
# Our current model has a low standard error, so the prediction is very accurate when testing our prediction data. However, the reason for low or even no error may come from under sampled or flawed dataset, so the improvement of dataset quality may still be needed to prove the accuracy of the model further.

# %% [markdown]
# ## Method

# %% [markdown]
# ## Data

# %% [markdown]
# ### Brief

# %% [markdown]
# The data set used in this project is 12 characteristics of the Portuguese "Vinho Verde" wine collected during Oct., 2009 from [Wine Quality Data Set](https://archive.ics.uci.edu/ml/datasets/wine+quality).

# %% [markdown]
# ### Reading in the white wine dataset from Jupyter

# %%
data = read_delim("data/winequality-white.csv", ";")
# Out:
# Rows: 4898 Columns: 12
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ";"
# dbl (12): fixed acidity, volatile acidity, citric acid, residual sugar, chlo...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# ### Cleaning the data
# Data cleaning was performed as following steps:
# 1. Changing the column names so they don't have spaces in between them <br>
# 2. Labelling the white wine quality as categorical values and setting them as a factor for the dataset<br>
# 3. Set each column as a double expect quality column

# %%
new_names <- c("fixed_acidity", "volatile_acidity", "citric_acid", "residual_sugar", "chlorides", "free_sulfur_dioxide", "total_sulfur_dioxide", "density", "pH", "sulphates", "alcohol", "quality")
data <- rename(data, !!!setNames(names(data), new_names))

# colnames(data)
data$quality <- as.integer(data$quality)
data$fixed_acidity<- as.double(data$fixed_acidity)
data$volatile_acidity<- as.double(data$volatile_acidity)
data$citric_acid<- as.double(data$citric_acid)
data$residual_sugar<- as.double(data$residual_sugar)
data$free_sulfur_dioxide<- as.double(data$free_sulfur_dioxide)
data$total_sulfur_dioxide<- as.double(data$total_sulfur_dioxide)
data$chlorides<- as.double(data$chlorides)
data$density<- as.double(data$density)
data$pH<- as.double(data$pH)
data$sulphates<- as.double(data$sulphates)
data$alcohol<- as.double(data$alcohol)
data$quality[data$quality==1] = "unsatisfactory"
data$quality[data$quality==2] = "unsatisfactory"
data$quality[data$quality==3] = "unsatisfactory"
data$quality[data$quality==4] = "unsatisfactory"
data$quality[data$quality==5] = "average"
data$quality[data$quality==6] = "average"
data$quality[data$quality==7] = "Great"
data$quality[data$quality==8] = "Great"
data$quality[data$quality==9] = "Great"
data$quality = as.factor(data$quality)
table(data$quality)
data
# Out:
#        average          Great unsatisfactory
#           3655           1060            183
#      fixed_acidity volatile_acidity citric_acid residual_sugar chlorides
# 1    7.0           0.27             0.36        20.70          0.045
# 2    6.3           0.30             0.34         1.60          0.049
# 3    8.1           0.28             0.40         6.90          0.050
# 4    7.2           0.23             0.32         8.50          0.058
# 5    7.2           0.23             0.32         8.50          0.058
# 6    8.1           0.28             0.40         6.90          0.050
# 7    6.2           0.32             0.16         7.00          0.045
# 8    7.0           0.27             0.36        20.70          0.045
# 9    6.3           0.30             0.34         1.60          0.049
# 10   8.1           0.22             0.43         1.50          0.044
# 11   8.1           0.27             0.41         1.45          0.033
# 12   8.6           0.23             0.40         4.20          0.035
# 13   7.9           0.18             0.37         1.20          0.040
# 14   6.6           0.16             0.40         1.50          0.044
# 15   8.3           0.42             0.62        19.25          0.040
# 16   6.6           0.17             0.38         1.50          0.032
# 17   6.3           0.48             0.04         1.10          0.046
# 18   6.2           0.66             0.48         1.20          0.029
# 19   7.4           0.34             0.42         1.10          0.033
# 20   6.5           0.31             0.14         7.50          0.044
# 21   6.2           0.66             0.48         1.20          0.029
# 22   6.4           0.31             0.38         2.90          0.038
# 23   6.8           0.26             0.42         1.70          0.049
# 24   7.6           0.67             0.14         1.50          0.074
# 25   6.6           0.27             0.41         1.30          0.052
# 26   7.0           0.25             0.32         9.00          0.046
# 27   6.9           0.24             0.35         1.00          0.052
# 28   7.0           0.28             0.39         8.70          0.051
# 29   7.4           0.27             0.48         1.10          0.047
# 30   7.2           0.32             0.36         2.00          0.033
# ⋮    ⋮             ⋮                ⋮           ⋮              ⋮
# 4869 5.8           0.230            0.31         4.50          0.046
# 4870 6.6           0.240            0.33        10.10          0.032
# 4871 6.1           0.320            0.28         6.60          0.021
# 4872 5.0           0.200            0.40         1.90          0.015
# 4873 6.0           0.420            0.41        12.40          0.032
# 4874 5.7           0.210            0.32         1.60          0.030
# 4875 5.6           0.200            0.36         2.50          0.048
# 4876 7.4           0.220            0.26         1.20          0.035
# 4877 6.2           0.380            0.42         2.50          0.038
# 4878 5.9           0.540            0.00         0.80          0.032
# 4879 6.2           0.530            0.02         0.90          0.035
# 4880 6.6           0.340            0.40         8.10          0.046
# 4881 6.6           0.340            0.40         8.10          0.046
# 4882 5.0           0.235            0.27        11.75          0.030
# 4883 5.5           0.320            0.13         1.30          0.037
# 4884 4.9           0.470            0.17         1.90          0.035
# 4885 6.5           0.330            0.38         8.30          0.048
# 4886 6.6           0.340            0.40         8.10          0.046
# 4887 6.2           0.210            0.28         5.70          0.028
# 4888 6.2           0.410            0.22         1.90          0.023
# 4889 6.8           0.220            0.36         1.20          0.052
# 4890 4.9           0.235            0.27        11.75          0.030
# 4891 6.1           0.340            0.29         2.20          0.036
# 4892 5.7           0.210            0.32         0.90          0.038
# 4893 6.5           0.230            0.38         1.30          0.032
# 4894 6.2           0.210            0.29         1.60          0.039
# 4895 6.6           0.320            0.36         8.00          0.047
# 4896 6.5           0.240            0.19         1.20          0.041
# 4897 5.5           0.290            0.30         1.10          0.022
# 4898 6.0           0.210            0.38         0.80          0.020
#      free_sulfur_dioxide total_sulfur_dioxide density pH   sulphates alcohol
# 1    45                  170                  1.0010  3.00 0.45       8.8
# 2    14                  132                  0.9940  3.30 0.49       9.5
# 3    30                   97                  0.9951  3.26 0.44      10.1
# 4    47                  186                  0.9956  3.19 0.40       9.9
# 5    47                  186                  0.9956  3.19 0.40       9.9
# 6    30                   97                  0.9951  3.26 0.44      10.1
# 7    30                  136                  0.9949  3.18 0.47       9.6
# 8    45                  170                  1.0010  3.00 0.45       8.8
# 9    14                  132                  0.9940  3.30 0.49       9.5
# 10   28                  129                  0.9938  3.22 0.45      11.0
# 11   11                   63                  0.9908  2.99 0.56      12.0
# 12   17                  109                  0.9947  3.14 0.53       9.7
# 13   16                   75                  0.9920  3.18 0.63      10.8
# 14   48                  143                  0.9912  3.54 0.52      12.4
# 15   41                  172                  1.0002  2.98 0.67       9.7
# 16   28                  112                  0.9914  3.25 0.55      11.4
# 17   30                   99                  0.9928  3.24 0.36       9.6
# 18   29                   75                  0.9892  3.33 0.39      12.8
# 19   17                  171                  0.9917  3.12 0.53      11.3
# 20   34                  133                  0.9955  3.22 0.50       9.5
# 21   29                   75                  0.9892  3.33 0.39      12.8
# 22   19                  102                  0.9912  3.17 0.35      11.0
# 23   41                  122                  0.9930  3.47 0.48      10.5
# 24   25                  168                  0.9937  3.05 0.51       9.3
# 25   16                  142                  0.9951  3.42 0.47      10.0
# 26   56                  245                  0.9955  3.25 0.50      10.4
# 27   35                  146                  0.9930  3.45 0.44      10.0
# 28   32                  141                  0.9961  3.38 0.53      10.5
# 29   17                  132                  0.9914  3.19 0.49      11.6
# 30   37                  114                  0.9906  3.10 0.71      12.3
# ⋮    ⋮                   ⋮                    ⋮       ⋮    ⋮         ⋮
# 4869 42                  124                  0.99324 3.31 0.64      10.800000
# 4870  8                   81                  0.99626 3.19 0.51       9.800000
# 4871 29                  132                  0.99188 3.15 0.36      11.450000
# 4872 20                   98                  0.98970 3.37 0.55      12.050000
# 4873 50                  179                  0.99622 3.14 0.60       9.700000
# 4874 33                  122                  0.99044 3.33 0.52      11.900000
# 4875 16                  125                  0.99282 3.49 0.49      10.000000
# 4876 18                   97                  0.99245 3.12 0.41       9.700000
# 4877 34                  117                  0.99132 3.36 0.59      11.600000
# 4878 12                   82                  0.99286 3.25 0.36       8.800000
# 4879  6                   81                  0.99234 3.24 0.35       9.500000
# 4880 68                  170                  0.99494 3.15 0.50       9.533333
# 4881 68                  170                  0.99494 3.15 0.50       9.533333
# 4882 34                  118                  0.99540 3.07 0.50       9.400000
# 4883 45                  156                  0.99184 3.26 0.38      10.700000
# 4884 60                  148                  0.98964 3.27 0.35      11.500000
# 4885 68                  174                  0.99492 3.14 0.50       9.600000
# 4886 68                  170                  0.99494 3.15 0.50       9.550000
# 4887 45                  121                  0.99168 3.21 1.08      12.150000
# 4888  5                   56                  0.98928 3.04 0.79      13.000000
# 4889 38                  127                  0.99330 3.04 0.54       9.200000
# 4890 34                  118                  0.99540 3.07 0.50       9.400000
# 4891 25                  100                  0.98938 3.06 0.44      11.800000
# 4892 38                  121                  0.99074 3.24 0.46      10.600000
# 4893 29                  112                  0.99298 3.29 0.54       9.700000
# 4894 24                   92                  0.99114 3.27 0.50      11.200000
# 4895 57                  168                  0.99490 3.15 0.46       9.600000
# 4896 30                  111                  0.99254 2.99 0.46       9.400000
# 4897 20                  110                  0.98869 3.34 0.38      12.800000
# 4898 22                   98                  0.98941 3.26 0.32      11.800000
#      quality
# 1    average
# 2    average
# 3    average
# 4    average
# 5    average
# 6    average
# 7    average
# 8    average
# 9    average
# 10   average
# 11   average
# 12   average
# 13   average
# 14   Great
# 15   average
# 16   Great
# 17   average
# 18   Great
# 19   average
# 20   average
# 21   Great
# 22   Great
# 23   Great
# 24   average
# 25   average
# 26   average
# 27   average
# 28   average
# 29   average
# 30   Great
# ⋮    ⋮
# 4869 average
# 4870 average
# 4871 Great
# 4872 average
# 4873 average
# 4874 average
# 4875 average
# 4876 average
# 4877 Great
# 4878 average
# 4879 unsatisfactory
# 4880 average
# 4881 average
# 4882 average
# 4883 average
# 4884 average
# 4885 average
# 4886 average
# 4887 Great
# 4888 Great
# 4889 average
# 4890 average
# 4891 average
# 4892 average
# 4893 average
# 4894 average
# 4895 average
# 4896 average
# 4897 Great
# 4898 average

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Counting and graphinh all the different quality of wines

# %%
options(repr.plot.width = 12, repr.plot.height = 8)
data %>%
  group_by(quality) %>%
  tally()

quality_distribution <- data %>% 
    ggplot(aes(x = quality, fill = quality)) +
    geom_bar() +
    labs(x = "Wine Wine Quality", y = "Number of Occurances", fill = "Wine Category") +
    ggtitle("Total Count of White Wine Quality")
quality_distribution
# Out:
#   quality        n
# 1 average        3655
# 2 Great          1060
# 3 unsatisfactory  183
# plot without title

# %% [markdown]
# **Table.1. & Figure. 1. Total Count of White Wine Quality**

# %% [markdown]
# ### Looking at the correlation between all predictors and the predicted

# %%
ggpairs(data)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# **Figure.2. Correlation between predictor variables and response variable**

# %% [markdown]
# ### Splitting a training and testing data set and creating a recipe for it

# %%
set.seed(5678)

split <- initial_split(data, prop = 0.75, strata = quality)
training <- training(split)
testing <- testing(split)

# %%
set.seed(5678)
recipe <- recipe(quality ~ . , data = data)%>%
    step_center(all_predictors()) %>%
    step_scale(all_predictors())
recipe
# Out:
# Recipe
#
# Inputs:
#
#       role #variables
#    outcome          1
#  predictor         11
#
# Operations:
#
# Centering for all_predictors()
# Scaling for all_predictors()

# %% [markdown]
# ### Making a 10-fold cross validation for wine quality training data set

# %%
set.seed(5678)

vfold <- vfold_cv(data, v = 10, strata = quality)
knn_tune <- nearest_neighbor(weight_func = "rectangular", neighbors = tune()) %>%
    set_engine("kknn") %>%
    set_mode("classification")
knn_tune
# Out:
# K-Nearest Neighbor Model Specification (classification)
#
# Main Arguments:
#   neighbors = tune()
#   weight_func = rectangular
#
# Computational engine: kknn

# %% [markdown]
# ### Setting up the workflow for the recipe and knn fold

# %%
set.seed(5678)
knn_results <- workflow() %>%
    add_recipe(recipe) %>%
    add_model(knn_tune) %>%
    tune_grid(resamples = vfold, grid = 20) %>%
    collect_metrics()
knn_results
# Out:
#    neighbors .metric  .estimator mean      n  std_err     .config
# 1   1        accuracy multiclass 0.8184920 10 0.004661833 Preprocessor1_Model01
# 2   1        roc_auc  hand_till  0.7199821 10 0.008616684 Preprocessor1_Model01
# 3   2        accuracy multiclass 0.8184920 10 0.004661833 Preprocessor1_Model02
# 4   2        roc_auc  hand_till  0.7451150 10 0.008919522 Preprocessor1_Model02
# 5   3        accuracy multiclass 0.7856181 10 0.006387570 Preprocessor1_Model03
# 6   3        roc_auc  hand_till  0.7606450 10 0.009469090 Preprocessor1_Model03
# 7   4        accuracy multiclass 0.7852116 10 0.006164248 Preprocessor1_Model04
# 8   4        roc_auc  hand_till  0.7680831 10 0.009262905 Preprocessor1_Model04
# 9   5        accuracy multiclass 0.7948076 10 0.006379523 Preprocessor1_Model05
# 10  5        roc_auc  hand_till  0.7723467 10 0.008897464 Preprocessor1_Model05
# 11  6        accuracy multiclass 0.7962375 10 0.006226716 Preprocessor1_Model06
# 12  6        roc_auc  hand_till  0.7789887 10 0.009952988 Preprocessor1_Model06
# 13  7        accuracy multiclass 0.7937805 10 0.007570418 Preprocessor1_Model07
# 14  7        roc_auc  hand_till  0.7828000 10 0.011020449 Preprocessor1_Model07
# 15  8        accuracy multiclass 0.7939850 10 0.007240106 Preprocessor1_Model08
# 16  8        roc_auc  hand_till  0.7800194 10 0.010934877 Preprocessor1_Model08
# 17  9        accuracy multiclass 0.7896989 10 0.005764190 Preprocessor1_Model09
# 18  9        roc_auc  hand_till  0.7822216 10 0.010670093 Preprocessor1_Model09
# 19 11        accuracy multiclass 0.7892929 10 0.004391875 Preprocessor1_Model10
# 20 11        roc_auc  hand_till  0.7857614 10 0.010636675 Preprocessor1_Model10
# 21 12        accuracy multiclass 0.7894965 10 0.004443388 Preprocessor1_Model11
# 22 12        roc_auc  hand_till  0.7871754 10 0.011647560 Preprocessor1_Model11
# 23 14        accuracy multiclass 0.7860213 10 0.004801220 Preprocessor1_Model12
# 24 14        roc_auc  hand_till  0.7876636 10 0.011631864 Preprocessor1_Model12
# 25 15        accuracy multiclass 0.7843874 10 0.005770757 Preprocessor1_Model13
# 26 15        roc_auc  hand_till  0.7893617 10 0.011436051 Preprocessor1_Model13

# %% [markdown]
# ### Graphing the accuray and the KNN

# %%
set.seed(5678)

accuracies <- knn_results %>% 
    filter(.metric == "accuracy")

cross_plot <- ggplot(accuracies, aes(x = neighbors, y = mean))+
    geom_point() +
    geom_line() +
    labs(x = "Neighbors", y = "Accuracy", title = "Accuracy Estimate vs KNN") + 
    theme(text = element_text(size = 20)) 
cross_plot
# Out:
# plot without title

# %% [markdown]
# **Figure.3. The relationship between accuracy and the number of neighbors**

# %% [markdown]
# ### Finding the most accurate K value

# %%
accurate_k <-  accuracies %>% filter(mean == max(mean)) %>% slice(1)
accurate_k

k <- accurate_k %>% pull(neighbors)
k
# Out:
#   neighbors .metric  .estimator mean     n  std_err     .config
# 1 1         accuracy multiclass 0.818492 10 0.004661833 Preprocessor1_Model01
# [1] 1

# %% [markdown]
# **Table.2. The neighbor wiht the highest classification accuracy and its error on the test data**

# %% [markdown]
# ### Using the most accurate K value to then build our Classification Model

# %%
set.seed(5678)

spec <- nearest_neighbor(weight_func = "rectangular", neighbors = k) %>%
    set_engine("kknn") %>%
    set_mode("classification")
spec

fit <- workflow() %>%
    add_recipe(recipe) %>%
    add_model(spec) %>%
    fit(data = data)
fit
# Out:
# K-Nearest Neighbor Model Specification (classification)
#
# Main Arguments:
#   neighbors = k
#   weight_func = rectangular
#
# Computational engine: kknn
# ══ Workflow [trained] ══════════════════════════════════════════════════════════
# Preprocessor: Recipe
# Model: nearest_neighbor()
#
# ── Preprocessor ────────────────────────────────────────────────────────────────
# 2 Recipe Steps
#
# • step_center()
# • step_scale()
#
# ── Model ───────────────────────────────────────────────────────────────────────
#
# Call:
# kknn::train.kknn(formula = ..y ~ ., data = data, ks = min_rows(1L,     data, 5), kernel = ~"rectangular")
#
# Type of response variable: nominal
# Minimal misclassification: 0.1723152
# Best kernel: rectangular
# Best k: 1

# %% [markdown]
# ### Using the new classification model to build to predict the accuracy and shown through a Confusion Matrix

# %%
set.seed(5678)

prediction <- predict(fit, testing) %>%
    bind_cols(testing) 
# mnist_predictions

mnist_metrics <- prediction %>%
    metrics(truth = quality, estimate = .pred_class) 
mnist_metrics

conf_mat <- prediction %>%
    conf_mat(truth = quality, estimate = .pred_class) 
conf_mat
# Out:
#   .metric  .estimator .estimate
# 1 accuracy multiclass 1
# 2 kap      multiclass 1
#                 Truth
# Prediction       average Great unsatisfactory
#   average            912     0              0
#   Great                0   263              0
#   unsatisfactory       0     0             50

# %% [markdown]
# **Table.3. The classification confusion matrix with k = 1**

# %% [markdown]
# # Results
#  Data was split into 75% training and 25% testing sets. The relationship between predictor variables(physicochemical varialbe) and response variable listed in Figure 2 was visualitzed to evaluate the utility for modelling. The result showed that there was no evidence of having strong relationship between them was omitted from modeling.
#  We first perform a 10-fold cross validation test. We then created a workflow based on the cross validation and recipe that we made.
#  <Br>
#  After using our KNN Classification, we figured out that our best k-neighbour would be 1 as the result shown in Figure 3 and Table 2. Then we use the best_k to predict our accuracy and present it through a confusion matrix in Table 3. We got that the estimate to be 1 exactly. We also found that the standard error for our best k was very low: 0.00466. This means that our prediction was very accurate when testing our prediction data.

# %% [markdown]
# # Discussion
# When we got the esitmate of 1 that means that our data was exactly correlated and no error was made between the prediction when we are training and testing the data. Some conclusions can we drawn from the estimate. Our original data maybe under sampled or flawed so thus when we are performing our classification we would get over repeated values and thus having no error when training our data. On the other hand, when we trained our data the seed of our data ran the exact operations needed to have the perfert perdict however this is extremely unlikely. Moreover, since we are including all of the predictors that are used in this data therefore creating such a high estiamte for the predciton because the more the predictors we use the higher the R^2 and adjusted R^2 we get from the values.
